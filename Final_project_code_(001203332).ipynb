# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# Top Product Categories of left subset of the dataset:
#
# In total six product categories are available: computer and accessories, video games, office products, other electronics, camera and photo, luggage, and travel gear. Computer and accessories is the biggest category which covers more than 80% of the products available in the dataset. Video games is the second most popular category having 12 products and office products is the third category in line having 11 products.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter
df = pd.read_json("/content/testset_1500.json", lines=True)

dfx = df['category_left'].unique()
#print(dfx)

dfy = df['category_left'].value_counts()
print(dfy)

fig = plt.figure(figsize=(8, 8))
ax = fig.add_axes([0,0,1,1])
ax.bar(dfx, dfy)


plt.title("Top Product Categories (Left data subset)")
plt.xlabel("Categories of Product")
plt.xticks(rotation=75)

plt.show()
# Out:
# Computers_and_Accessories    1458
# Video_Games                    12
# Office_Products                11
# Other_Electronics               8
# Camera_and_Photo                6
# Luggage_and_Travel_Gear         5
# Name: category_left, dtype: int64

# %% [markdown]
# Top Product Categories of right subset of the dataset:
#
# Top categories in data subset right, computer and accessories dominate here as well, covering more than 80% of the total dataset. Second most popular category is other electronics and video games are on the third.

# %%
dfx = df['category_right'].unique()

dfy = df['category_right'].value_counts()
print(dfy)

fig = plt.figure(figsize=(8, 8))
ax = fig.add_axes([0,0,1,1])
ax.bar(dfx, dfy)


plt.title("Top Product Categories (Right data subset)")
plt.xlabel("Categories of Product")
plt.xticks(rotation=75)

plt.show()
# Out:
# Computers_and_Accessories     1459
# Other_Electronics               12
# Video_Games                      9
# Office_Products                  7
# Camera_and_Photo                 5
# Musical_Instruments              3
# Luggage_and_Travel_Gear          3
# Cellphones_and_Accessories       1
# Tools_and_Home_Improvement       1
# Name: category_right, dtype: int64

# %% [markdown]
# Top Brands of left subset of dataset:
#
# A Total of 92 unique brands are available in the left subset of the dataset. HP enterprise is the most popular brand within our dataset. All the products of HP enterprise are listed under the category of computer and accessories. An exact number of 210 products of HP enterprises are available in the dataset. Corsair is the second most popular brand with 60 unique products. Corsair largely contributed to the category of video games and other electronics. Asus is third on the list with 41 unique products. AMD and Intel are fourth and fifth respectively.

# %%
dfx = df['brand_left'].unique()

dfy = df['brand_left'].value_counts()
print(dfy)

plt.style.use('ggplot')
plt.rcParams.update({'text.color' : "black", 'font.size': 11 })
plotdata = pd.DataFrame(dfy)
plotdata.iloc[0:5].plot(kind='barh', figsize=(6,6))


plt.title("Top 5 Brands (Left data subset)")
plt.xlabel("Number of Products")

plt.show()
# Out:
# "HP Enterprise"      210
# "Corsair"@en          60
# "Asus"@en             41
# "AMD"@en              36
# "Intel"@en            34
#                     ...
# "GEEKPRO"@en-US        1
# "Samsung/transce"      1
# "Crucial"              1
# "150"@en               1
# "Patriot"@en-US        1
# Name: brand_left, Length: 92, dtype: int64

# %% [markdown]
# Top Brands of right subset of dataset:
#
# HP is the most popular brand with 256 unique products. Corsair
# is second in line with 45 unique products. Intel with 40 unique products is third most popular brand, AMD and Intel are forth and fifth respectively.

# %%
dfx = df['brand_right'].unique()

dfy = df['brand_right'].value_counts()
print(dfy)

plt.style.use('ggplot')
plt.rcParams.update({'text.color' : "black", 'font.size': 11 })
plotdata = pd.DataFrame(dfy)
plotdata.iloc[0:5].plot(kind='barh', figsize=(6,6))

plt.title("Top 5 Brands (Right data subset)")
plt.xlabel("Number of Products")

plt.show()
# Out:
# "HP Enterprise"    256
# "Corsair"@en        45
# "Intel"@en          40
# "AMD"@en            33
# "Asus"@en           30
#                   ...
# "Acer "              1
# "SANDISK"@en         1
# "OptiPlex"@en        1
# "IBM"                1
# "LOGITECH"           1
# Name: brand_right, Length: 135, dtype: int64

# %% [markdown]
# Top products of left subset of dataset:
#
# A total of 598 unique products are available in the left subset of the dataset. HyperX Fury is the most popular product in our dataset. It has two variants, one with DDR3 8 GB RAM and the other with DDR4 4 GB RAM. Apple MAC mini is one of the top products along with AMD Ryzen 7 and Kingston USB. Samsung 850 EVO internal SSD is one of the last popular products in our dataset.

# %%
dfx = df['title_left'].unique()

dfy = df['title_left'].value_counts()
print(dfy)

plt.style.use('ggplot')
plt.rcParams.update({'text.color' : "black", 'font.size': 11 })
plotdata = pd.DataFrame(dfy)
plotdata.iloc[0:9].plot(kind='barh', figsize=(8,8))

plt.title("Top 10 Products (Left data subset)")
plt.xlabel("Number of Products")

plt.show()
# Out:
#  "HyperX FURY - DDR3 8 GB                                                                                                               9
#  "HyperX FURY - DDR4 4 GB                                                                                                               9
#  "Apple Mac Mini 1.4GHz                                                                                                                 9
#  "AMD Ryzen 7 1800X 8 Core AM4 CPU/Processor"@en CPU/Processor LN78869 - YD180XBCAEWOF | SCAN UK"@en                                    9
#  "Kingston USB 3.1 Type A+C microDuo 3C Flash Drive 32GB"@en 32GB LN65980 - DTDUO3C/32GB | SCAN UK"@en                                  9
#                                                                                                                                        ..
#  "HP Chromebook 14 G4 - 14" Celeron N2840 2 GB RAM 16 SSD US"@en OETC Consortium Store"@en                                              1
# ...

# %% [markdown]
# Top products of right subset of dataset:
#
# A total of 1312 products are available in the right subset of the dataset. Top 10 products are visualized in the chart below.

# %%
dfx = df['title_right'].unique()

dfy = df['title_right'].value_counts()
print(dfy)

plt.style.use('ggplot')
plt.rcParams.update({'text.color' : "black", 'font.size': 11 })
plotdata = pd.DataFrame(dfy)
plotdata.iloc[0:9].plot(kind='barh', figsize=(8,8))

plt.title("Top 10 Products (Right data subset)")
plt.xlabel("Number of Products")

plt.show()
# Out:
#  "Apple iMac 27""                                                                                                                            7
#  "Buy Online | MSI GeForce GTX 1080 ARMOR 8G OC Graphic Card Price in India"@en-US                                                           3
#  "Fujitsu PRIMERGY RX100 S7"                                                                                                                 3
#  "Acer Chromebook C710 B847Cii - Specificaties "@NL Tweakers"@NL                                                                             3
#  "662078-B21 HP Intel Xeon E5-2650L 1.8GHz BL460c G8", "Null" "New 662078-B21 G8 Wholesale Price 662078-B21"                                 3
#                                                                                                                                             ..
# ...

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_left                 1500 non-null   int64
#  1   category_left           1500 non-null   object
#  2   title_left              1500 non-null   object
#  3   description_left        1333 non-null   object
#  4   brand_left              865 non-null    object
#  5   price_left              339 non-null    object
#  6   keyValuePairs_left      475 non-null    object
#  7   specTableContent_left   505 non-null    object
#  8   id_right                1500 non-null   int64
#  9   category_right          1500 non-null   object
#  10  title_right             1500 non-null   object
#  11  description_right       1281 non-null   object
#  12  brand_right             856 non-null    object
#  13  price_right             344 non-null    object
# ...

# %% [markdown]
# Detect missing values.

# %%
print(df.isnull())
# Out:
# id_left                      0
# category_left                0
# title_left                   0
# description_left           167
# brand_left                 635
# price_left                1161
# keyValuePairs_left        1025
# specTableContent_left      995
# id_right                     0
# category_right               0
# title_right                  0
# description_right          219
# brand_right                644
# price_right               1156
# keyValuePairs_right       1076
# specTableContent_right    1030
# pair_id                      0
# dtype: int64

# %% [markdown]
# **Data Formatting**
#
# Selected features are read from the dataset and converted into a CSV file.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter
import csv
df = pd.read_json("/content/testset_1500.json", lines=True)

left_df = df[['id_left', 'title_left', 'category_left', 'description_left', 'pair_id']]
print(left_df)

left_df.to_csv()
# Out:
#        id_left                                         title_left  \
# 0      1656083   "Corsair Vengeance 8Gb (2x4Gb) DDR3 1600MHz C...
# 1      1220565   "488039-B21 HP X5470 3.33GHz ML370 G5", "Null...
# 2     10969978   "Corsair Air Series SP120 PWM High Performanc...
# 3      1749942   "Speck Flaptop Sleeve for MacBook Air 13""@en...
# 4       403680   "Asus M5A99X PRO R2.0 AMD 990X (Socket AM3+) ...
# ...        ...                                                ...
# 1495     72675      "Null" "495942-B21 HP E5506 2.13GHz ML370 G6"
# 1496   2365521              "AMD Ryzen Threadripper 1950X Box"@es
# 1497   2807522   "WD Red 6TB NAS Hard Disk Drive - 5400 RPM Cl...
# 1498    268014   "Samsung 850 EVO 250 GB Internal SSD" " Samsu...
# 1499    548194                 "HyperX Fury 64Go 2133 MHz (4x16)"
#
#                   category_left  \
# 0     Computers_and_Accessories
# 1     Computers_and_Accessories
# 2     Computers_and_Accessories
# 3     Computers_and_Accessories
# ...

# %%
right_df = df[['id_left', 'title_left', 'category_left', 'description_left', 'pair_id']]
print(right_df)

right_df.to_csv()
# Out:
#        id_left                                         title_left  \
# 0      1656083   "Corsair Vengeance 8Gb (2x4Gb) DDR3 1600MHz C...
# 1      1220565   "488039-B21 HP X5470 3.33GHz ML370 G5", "Null...
# 2     10969978   "Corsair Air Series SP120 PWM High Performanc...
# 3      1749942   "Speck Flaptop Sleeve for MacBook Air 13""@en...
# 4       403680   "Asus M5A99X PRO R2.0 AMD 990X (Socket AM3+) ...
# ...        ...                                                ...
# 1495     72675      "Null" "495942-B21 HP E5506 2.13GHz ML370 G6"
# 1496   2365521              "AMD Ryzen Threadripper 1950X Box"@es
# 1497   2807522   "WD Red 6TB NAS Hard Disk Drive - 5400 RPM Cl...
# 1498    268014   "Samsung 850 EVO 250 GB Internal SSD" " Samsu...
# 1499    548194                 "HyperX Fury 64Go 2133 MHz (4x16)"
#
#                   category_left  \
# 0     Computers_and_Accessories
# 1     Computers_and_Accessories
# 2     Computers_and_Accessories
# 3     Computers_and_Accessories
# ...

# %% [markdown]
# **Data Labeling**
#
# Same products are labelled as 1 and different products are labbeled as 0.

# %%
data_left = pd.read_csv("/content/data_left.csv")
data_right = pd.read_csv("/content/data_right.csv")


data_left['concat'] = data_left['id_left'].astype(str) + '#' + data_right['id_right'].astype(str)

for i in range(len(data_left)):
  data_left['concat'] = data_left.loc[0, 'id_left'].astype(str) + '#' + data_right.loc[i, 'id_right'].astype(str)
  #for j in range(len(data_right)):
  if (data_left.loc[0, 'pair_id'] == data_left.loc[i, 'concat']):
    data_left.loc[i, 'match'] = 1
# Out:
#     id_left                                         title_left  \
# 0   1656083   "Corsair Vengeance 8Gb (2x4Gb) DDR3 1600MHz C...
# 1   1220565   "488039-B21 HP X5470 3.33GHz ML370 G5", "Null...
# 2  10969978   "Corsair Air Series SP120 PWM High Performanc...
# 3   1749942   "Speck Flaptop Sleeve for MacBook Air 13""@en...
#
#                category_left  \
# 0  Computers_and_Accessories
# 1  Computers_and_Accessories
# 2  Computers_and_Accessories
# 3  Computers_and_Accessories
#
#                                     description_left              pair_id  \
# 0  "Corsair Vengeance 8Gb (2x4Gb) DDR3 1600MHz Ca...      1656083#4082241
# 1  "Description:Intel Xeon X5470 ML370 G5 (3.33GH...      1220565#4215042
# 2  "Size: 120mm x 25mm, Operating Voltage: 7V-12V...  10969978#-128473760
# 3                                                NaN    1749942#-88566620
#
#                 concat
# 0  1656083#-88566620.0
# 1  1656083#-88566620.0
# 2  1656083#-88566620.0
# 3  1656083#-88566620.0

# %% [markdown]
# **Buidling Machine Learning Model**
#
# 1. **Vectorizer:**
# CountVectorizer class from the sklearn.feature_extraction.text library. There are several critical arguments that must be given to the class's function. The first argument is set to 1500, which is the maximum number of features. This is because when you utilize the bag of words technique to convert words to numbers, all of the unique words in all of the documents are turned into features.
#
# 2. **TfidfTransformer:**
# Transform a count matrix to a normalized tf or tf-idf representation Tf means term-frequency while tf-idf means term-frequency times inverse document-frequency. This is a common term weighting scheme in information retrieval, that has also found good use in document classification. The goal of using tf-idf instead of the raw frequencies of occurrence of a token in a given document is to scale down the impact of tokens that occur very frequently in a given corpus and that are hence empirically less informative than features that occur in a small fraction of the training corpus.
#
# 3. **Train and Test split:**
# The train test split() method is used to divide our data into train and test sets. To begin, we must divide our data into features (X) and labels (y). There are four segments in the dataframe: X train, X test, y train, and y test. Model training and fitting are done with the x and y train sets. The X and Y test sets are used to determine if the model correctly predicts the outputs/labels. We can test the train and test set sizes explicitly. It is suggested that we keep our train sets larger than our test sets.
#
# 4. **Implementation of ML model:**
# In this section, Random Forest model is implemented. All the explanation is available in the report.
#
# 5. **Model Evaluation:**
# Accuracy score, Mean squared error and Confusion matrix is used for the purpose of model evaluation.

# %%
import numpy as np
import re
import nltk
from sklearn.datasets import load_files
nltk.download('stopwords')
import pickle
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

data = pd.read_csv("/content/total.csv")
target = pd.read_csv("/content/target.csv")

vectorizer = CountVectorizer(max_features=1500, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))
data['title_left'] = vectorizer.fit_transform(data['title_left']).toarray()
data['title_right'] = vectorizer.fit_transform(data['title_right']).toarray()
data['category_left'] = vectorizer.fit_transform(data['category_left']).toarray()
data['category_right'] = vectorizer.fit_transform(data['category_right']).toarray()
#data['description_left'] = vectorizer.fit_transform(data['description_left']).toarray()
#data['description_right'] = vectorizer.fit_transform(data['description_right']).toarray()



X = data[['title_left', 'title_right', 'category_left', 'category_right']]

tfidfconverter = TfidfTransformer()
X = tfidfconverter.fit_transform(X).toarray()
y = target['match']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, shuffle = True)

classifier = RandomForestClassifier(n_estimators=1000, random_state=0)
classifier.fit(X_train, y_train) 

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test,y_pred)
print(cm)
print(classification_report(y_test,y_pred))
print("Accuracy = ", accuracy_score(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))


import seaborn as sns
ax = plt.axes()
ax.set_title("Confusion Matrix for Random Forest")
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [[290   3]
#  [301   6]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.99      0.66       293
#            1       0.67      0.02      0.04       307
#
#     accuracy                           0.49       600
#    macro avg       0.58      0.50      0.35       600
# weighted avg       0.58      0.49      0.34       600
#
# Accuracy =  0.49333333333333335
# Mean Squared Error:  0.5066666666666667

# %% [markdown]
# **Logistic Regression**
#
# In this section, multivariable logistic regression is used as a machine learning model. Accuracy score, Mean squared error and Confusion matrix is used to evaluate the model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, shuffle = True)
logreg = LogisticRegression(random_state=16)


logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

cm = confusion_matrix(y_test,y_pred)
print(cm)
print(classification_report(y_test,y_pred))
print("Accuracy = ",accuracy_score(y_test, y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))

ax = plt.axes()
ax.set_title("Confusion Matrix for Logistic Regression")
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# [[428   8]
#  [453  11]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.98      0.65       436
#            1       0.58      0.02      0.05       464
#
#     accuracy                           0.49       900
#    macro avg       0.53      0.50      0.35       900
# weighted avg       0.53      0.49      0.34       900
#
# Accuracy =  0.48777777777777775
# Mean Squared Error:  0.5122222222222222

# %% [markdown]
# **Support Vector Machine**
#
# In this section, support vector machine is used as a machine learning model. Accuracy score, Mean squared error and Confusion matrix is used to evaluate the model.

# %%
from sklearn import svm

clf = svm.SVC(kernel='linear') # Linear Kernel

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy = ",metrics.accuracy_score(y_test, y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))

cm = confusion_matrix(y_test, y_pred)
print(cm)
ax = plt.axes()
ax.set_title("Confusion Matrix for SVM")
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# Accuracy =  0.48777777777777775
# Mean Squared Error:  0.5122222222222222
# [[428   8]
#  [453  11]]
